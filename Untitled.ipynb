# %%
# !pip install boto3

# %%
import boto3

# %%
sagemaker = boto3.client('sagemaker')
ENDPOINT_NAME = 'random-model-5-2endpoint'
runtime= boto3.client('runtime.sagemaker')
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 sagemaker = boto3.client('sagemaker')
#       2 ENDPOINT_NAME = 'random-model-5-2endpoint'
#       3 runtime= boto3.client('runtime.sagemaker')
#
# File /opt/conda/lib/python3.8/site-packages/boto3/__init__.py:93, in client(*args, **kwargs)
#      87 def client(*args, **kwargs):
#      88     """
#      89     Create a low-level service client by name using the default session.
#      90
#      91     See :py:meth:`boto3.session.Session.client`.
#      92     """
# ---> 93     return _get_default_session().client(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/boto3/session.py:258, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
# ...
